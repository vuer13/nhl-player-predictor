# %%
import seaborn as sns
import pandas as pd

df = pd.read_csv("./data/final/assists_pred.csv")
sns.histplot(df["apg"])
# Out:
# <Axes: xlabel='apg', ylabel='Count'>

# %%
df = pd.read_csv("./data/final/goals_pred.csv")
sns.histplot(df["gpg"])
# Out:
# <Axes: xlabel='gpg', ylabel='Count'>

# %%
df = pd.read_csv("./data/final/games_played_pred.csv")
sns.histplot(df["games_played"])
# Out:
# <Axes: xlabel='games_played', ylabel='Count'>
