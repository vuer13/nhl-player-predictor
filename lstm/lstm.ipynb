# %%
import pandas as pd

# %%
df = pd.read_csv('../data/lstm_dataset_final.csv')

df = df.sort_values(by=['playerId', 'season'])

features = [
    'xGoals', 'pAssists', 'sAssists', 'sog', 'points', 'goals',
    'on_ice_chances', 'on_ice_goals', 'hits', 'penality_mins', 'pen_drawn',
    'corsi', 'xGoalsForAfterShifts', 'corsiForAfterShifts',
    'icetime_per_game', 'shot_percentage', 'points_per_60',
    'ixG-goals', 'ppg', 'apg', 'gpg',
    'xGoalsFor-goalsFor_team', 'age', 'age2', 'games_played_per',
    'pos_C', 'pos_D', 'pos_L', 'pos_R'
]
targets = ['next_games_played_per', 'next_goals_per_game', 'next_assists_per_game']

df = df.dropna(subset=features + targets)

for col in ['pos_C', 'pos_D', 'pos_L', 'pos_R']:
    df[col] = df[col].astype(int)
    
df.head()
# Out:
#       Unnamed: 0.1  Unnamed: 0  playerId  season           name position team  \
# 27              27         725   8448208    2015   Jaromir Jagr        R  FLA
# 1516          1516        1652   8448208    2016   Jaromir Jagr        R  FLA
# 840            840         137   8462038    2015     Shane Doan        R  ARI
# 129            129         484   8462042    2015  Jarome Iginla        R  COL
# 437            437         173   8464989    2015    Matt Cullen        C  PIT
#
#       games_played  xGoals  pAssists  ...  xGoalsFor-goalsFor_team  age2  \
# 27              79   19.76      21.0  ...                    -8.23  1849
# 1516            81   23.04      20.0  ...                    20.95  1936
# 840             72   21.16      12.0  ...                    -6.89  1521
# 129             82   18.66      16.0  ...                   -10.79  1444
# 437             82   11.16      11.0  ...                    -0.07  1521
#
#       games_played_per  pos_C  pos_D  pos_L  pos_R  next_games_played_per  \
# 27            0.963415      0      0      0      1               0.987805
# 1516          0.987805      0      0      0      1               0.268293
# 840           0.878049      0      0      0      1               0.890244
# 129           1.000000      0      0      0      1               0.963415
# 437           1.000000      1      0      0      0               0.878049
#
#       next_goals_per_game  next_assists_per_game
# 27               0.197531               0.370370
# 1516             0.045455               0.272727
# 840              0.068493               0.287671
# 129              0.177215               0.164557
# 437              0.180556               0.250000
#
# [5 rows x 47 columns]

# %%
from collections import defaultdict
import numpy as np

# %%
seq = 3

X = []
y = []

player_groups = df.groupby('playerId')

for player_id, group in player_groups:
    group = group.sort_values('season')
    
    for i in range(1, len(group)):
        start = max(0, i - seq)
        sequence = group.iloc[start:i][features].values
        target = group.iloc[i][targets].values
        
        padding_flag = np.zeros((seq, 1)) 
        
        if sequence.shape[0] == 1:
            sequence = np.vstack([sequence[0], sequence[0], sequence[0]])
            padding_flag[:2] = 1
        elif sequence.shape[0] == 2:
            sequence = np.vstack([sequence[0], sequence[0], sequence[1]])
            padding_flag[:1] = 1
        elif sequence.shape[0] > 3:
            sequence = sequence[-3:]
            
        sequence = np.concatenate([sequence, padding_flag], axis=1)
        
        X.append(sequence)
        y.append(target)

X = np.array(X)
y = np.array(y)

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_scaler = StandardScaler()
y_scaler = StandardScaler()

original_shape = X.shape

X_flat = X.reshape(-1, X.shape[2])
X_flat_scaled = X_scaler.fit_transform(X_flat)
X_seq_scaled = X_flat_scaled.reshape(original_shape)

y_seq_scaled = y_scaler.fit_transform(y)

# %%
from torch.utils.data import Dataset

# %%
class NHLDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
import torch.nn as nn

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, dropout):
        super(LSTM, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers,
                            batch_first=True, dropout=dropout if num_layers > 1 else 0.0)
        self.fc = nn.Linear(hidden_size, 3)

    def forward(self, x):
        _, (hn, _) = self.lstm(x)
        out = self.fc(hn[-1])
        return out

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader
import torch

# %%
X_train, X_val, y_train, y_val = train_test_split(X_seq_scaled, y_seq_scaled, test_size=0.2, random_state=42)

train_loader = DataLoader(NHLDataset(X_train, y_train), batch_size=64, shuffle=True)
val_loader = DataLoader(NHLDataset(X_val, y_val), batch_size=64)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import optuna

# %%
def objective(trial):
    hidden_size = trial.suggest_int("hidden_size", 64, 256)
    num_layers = trial.suggest_int("num_layers", 1, 3)
    dropout = trial.suggest_float("dropout", 0.0, 0.5)
    lr = trial.suggest_float("lr", 1e-4, 1e-2, log=True)
    batch_size = 64

    model = LSTM(input_size=X_train.shape[2], hidden_size=hidden_size,
                      num_layers=num_layers, dropout=dropout)

    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss()

    for epoch in range(10):
        model.train()
        for xb, yb in train_loader:
            pred = model(xb)
            loss = loss_fn(pred, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    model.eval()
    preds, targets = [], []
    with torch.no_grad():
        for xb, yb in val_loader:
            out = model(xb)
            preds.append(out.numpy())
            targets.append(yb.numpy())

    preds = np.concatenate(preds, axis=0)
    targets = np.concatenate(targets, axis=0)

    preds_orig = y_scaler.inverse_transform(preds)
    targets_orig = y_scaler.inverse_transform(targets)

    return r2_score(targets_orig, preds_orig)

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)
# Out:
# [I 2025-06-23 22:24:09,489] A new study created in memory with name: no-name-36aa34eb-b3b6-4d79-8ebb-aa857cc31eaa
# [I 2025-06-23 22:24:14,910] Trial 0 finished with value: 0.4511529505252838 and parameters: {'hidden_size': 137, 'num_layers': 2, 'dropout': 0.08107218019487555, 'lr': 0.004233968561589297}. Best is trial 0 with value: 0.4511529505252838.
# [I 2025-06-23 22:24:19,959] Trial 1 finished with value: 0.49558091163635254 and parameters: {'hidden_size': 135, 'num_layers': 2, 'dropout': 0.39858891382688816, 'lr': 0.0007002531794920246}. Best is trial 1 with value: 0.49558091163635254.
# [I 2025-06-23 22:24:23,753] Trial 2 finished with value: 0.49230265617370605 and parameters: {'hidden_size': 103, 'num_layers': 2, 'dropout': 0.13412897619271247, 'lr': 0.00028966749887620973}. Best is trial 1 with value: 0.49558091163635254.
# [I 2025-06-23 22:24:32,317] Trial 3 finished with value: 0.44730380177497864 and parameters: {'hidden_size': 166, 'num_layers': 3, 'dropout': 0.35774347436763904, 'lr': 0.007204570983990441}. Best is trial 1 with value: 0.49558091163635254.
# [I 2025-06-23 22:24:40,287] Trial 4 finished with value: 0.46965861320495605 and parameters: {'hidden_size': 228, 'num_layers': 2, 'dropout': 0.3620245151329391, 'lr': 0.004130403076146566}. Best is trial 1 with value: 0.49558091163635254.
# [I 2025-06-23 22:24:53,351] Trial 5 finished with value: 0.4601898193359375 and parameters: {'hidden_size': 240, 'num_layers': 3, 'dropout': 0.31854867157452194, 'lr': 0.009287575145494832}. Best is trial 1 with value: 0.49558091163635254.
# [I 2025-06-23 22:24:56,705] Trial 6 finished with value: 0.4235334098339081 and parameters: {'hidden_size': 220, 'num_layers': 1, 'dropout': 0.17797554980707098, 'lr': 0.008532695971897533}. Best is trial 1 with value: 0.49558091163635254.
# [I 2025-06-23 22:25:04,151] Trial 7 finished with value: 0.4537622630596161 and parameters: {'hidden_size': 138, 'num_layers': 3, 'dropout': 0.3214211659211717, 'lr': 0.0065296355404323245}. Best is trial 1 with value: 0.49558091163635254.
# [I 2025-06-23 22:25:10,937] Trial 8 finished with value: 0.49507489800453186 and parameters: {'hidden_size': 196, 'num_layers': 2, 'dropout': 0.4537845441276468, 'lr': 0.0002986148653480266}. Best is trial 1 with value: 0.49558091163635254.
# [I 2025-06-23 22:25:12,895] Trial 9 finished with value: 0.44502124190330505 and parameters: {'hidden_size': 97, 'num_layers': 1, 'dropout': 0.3339212789612809, 'lr': 0.005588444443530666}. Best is trial 1 with value: 0.49558091163635254.
# [I 2025-06-23 22:25:14,804] Trial 10 finished with value: 0.493725061416626 and parameters: {'hidden_size': 79, 'num_layers': 1, 'dropout': 0.48761222049896, 'lr': 0.0010673290498920962}. Best is trial 1 with value: 0.49558091163635254.
# [I 2025-06-23 22:25:21,125] Trial 11 finished with value: 0.49379763007164 and parameters: {'hidden_size': 185, 'num_layers': 2, 'dropout': 0.48999414785685813, 'lr': 0.00023489508211066012}. Best is trial 1 with value: 0.49558091163635254.
# [I 2025-06-23 22:25:27,796] Trial 12 finished with value: 0.4980787932872772 and parameters: {'hidden_size': 194, 'num_layers': 2, 'dropout': 0.4318231591624675, 'lr': 0.0006027848141311369}. Best is trial 12 with value: 0.4980787932872772.
# [I 2025-06-23 22:25:32,778] Trial 13 finished with value: 0.4859957695007324 and parameters: {'hidden_size': 139, 'num_layers': 2, 'dropout': 0.4128699967227719, 'lr': 0.0007755780825360174}. Best is trial 12 with value: 0.4980787932872772.
# [I 2025-06-23 22:25:35,978] Trial 14 finished with value: 0.4917231500148773 and parameters: {'hidden_size': 195, 'num_layers': 1, 'dropout': 0.23614648316587822, 'lr': 0.0008903448694451121}. Best is trial 12 with value: 0.4980787932872772.
# [I 2025-06-23 22:25:44,916] Trial 15 finished with value: 0.48914027214050293 and parameters: {'hidden_size': 163, 'num_layers': 3, 'dropout': 0.40483679772816195, 'lr': 0.0017581316329481522}. Best is trial 12 with value: 0.4980787932872772.
# [I 2025-06-23 22:25:49,390] Trial 16 finished with value: 0.4795949459075928 and parameters: {'hidden_size': 122, 'num_layers': 2, 'dropout': 0.2642643859584709, 'lr': 0.00012520931602932477}. Best is trial 12 with value: 0.4980787932872772.
# [I 2025-06-23 22:25:58,769] Trial 17 finished with value: 0.4900628626346588 and parameters: {'hidden_size': 179, 'num_layers': 3, 'dropout': 0.42106937695322544, 'lr': 0.0005285700316852689}. Best is trial 12 with value: 0.4980787932872772.
# [I 2025-06-23 22:26:01,966] Trial 18 finished with value: 0.47930479049682617 and parameters: {'hidden_size': 213, 'num_layers': 1, 'dropout': 0.2637508129903928, 'lr': 0.0025205117845904547}. Best is trial 12 with value: 0.4980787932872772.
# [I 2025-06-23 22:26:10,748] Trial 19 finished with value: 0.4950977861881256 and parameters: {'hidden_size': 252, 'num_layers': 2, 'dropout': 0.39200459025017537, 'lr': 0.0005877505079133427}. Best is trial 12 with value: 0.4980787932872772.
# [I 2025-06-23 22:26:13,965] Trial 20 finished with value: 0.4942326545715332 and parameters: {'hidden_size': 69, 'num_layers': 2, 'dropout': 0.034201441177981684, 'lr': 0.00042842884728340035}. Best is trial 12 with value: 0.4980787932872772.
# [I 2025-06-23 22:26:22,889] Trial 21 finished with value: 0.48813414573669434 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout': 0.39135451744887934, 'lr': 0.001460060311338818}. Best is trial 12 with value: 0.4980787932872772.
# [I 2025-06-23 22:26:29,954] Trial 22 finished with value: 0.48955321311950684 and parameters: {'hidden_size': 208, 'num_layers': 2, 'dropout': 0.4547790854313235, 'lr': 0.0005775787278979804}. Best is trial 12 with value: 0.4980787932872772.
# [I 2025-06-23 22:26:39,637] Trial 23 finished with value: 0.4881109297275543 and parameters: {'hidden_size': 254, 'num_layers': 2, 'dropout': 0.43988816515289203, 'lr': 0.0001276039141966605}. Best is trial 12 with value: 0.4980787932872772.
# [I 2025-06-23 22:26:45,028] Trial 24 finished with value: 0.49520957469940186 and parameters: {'hidden_size': 148, 'num_layers': 2, 'dropout': 0.29643156384559155, 'lr': 0.00037585441449233467}. Best is trial 12 with value: 0.4980787932872772.
# [I 2025-06-23 22:26:47,812] Trial 25 finished with value: 0.49287089705467224 and parameters: {'hidden_size': 148, 'num_layers': 1, 'dropout': 0.20737682891304707, 'lr': 0.00019666967049159116}. Best is trial 12 with value: 0.4980787932872772.
# [I 2025-06-23 22:26:53,587] Trial 26 finished with value: 0.4942161738872528 and parameters: {'hidden_size': 116, 'num_layers': 3, 'dropout': 0.28763329615436756, 'lr': 0.00039259771381243663}. Best is trial 12 with value: 0.4980787932872772.
# [I 2025-06-23 22:26:58,933] Trial 27 finished with value: 0.48811450600624084 and parameters: {'hidden_size': 154, 'num_layers': 2, 'dropout': 0.37039265969767626, 'lr': 0.0001901472280683274}. Best is trial 12 with value: 0.4980787932872772.
# [I 2025-06-23 22:27:04,896] Trial 28 finished with value: 0.4990440607070923 and parameters: {'hidden_size': 176, 'num_layers': 2, 'dropout': 0.33538865521448935, 'lr': 0.001118455827194482}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:27:11,013] Trial 29 finished with value: 0.49034807085990906 and parameters: {'hidden_size': 179, 'num_layers': 2, 'dropout': 0.34499013650286703, 'lr': 0.0013405120936902028}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:27:15,391] Trial 30 finished with value: 0.4862341582775116 and parameters: {'hidden_size': 121, 'num_layers': 2, 'dropout': 0.46079738532462744, 'lr': 0.0018147726633929756}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:27:21,206] Trial 31 finished with value: 0.48931530117988586 and parameters: {'hidden_size': 169, 'num_layers': 2, 'dropout': 0.29728071772059544, 'lr': 0.0006941139052014848}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:27:26,532] Trial 32 finished with value: 0.494849294424057 and parameters: {'hidden_size': 150, 'num_layers': 2, 'dropout': 0.2990475130643898, 'lr': 0.00040439956143523625}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:27:31,298] Trial 33 finished with value: 0.4952205419540405 and parameters: {'hidden_size': 129, 'num_layers': 2, 'dropout': 0.09821246499031383, 'lr': 0.0010063013809843513}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:27:35,038] Trial 34 finished with value: 0.47216442227363586 and parameters: {'hidden_size': 103, 'num_layers': 2, 'dropout': 0.11836239371222157, 'lr': 0.002895108758883689}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:27:41,713] Trial 35 finished with value: 0.4885025918483734 and parameters: {'hidden_size': 194, 'num_layers': 2, 'dropout': 0.127237437003169, 'lr': 0.0010863975383716327}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:27:48,735] Trial 36 finished with value: 0.46802565455436707 and parameters: {'hidden_size': 131, 'num_layers': 3, 'dropout': 0.02033773695622515, 'lr': 0.002199701787895407}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:27:54,497] Trial 37 finished with value: 0.48691651225090027 and parameters: {'hidden_size': 169, 'num_layers': 2, 'dropout': 0.18703909644873926, 'lr': 0.0012859629572597388}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:28:00,056] Trial 38 finished with value: 0.4829946458339691 and parameters: {'hidden_size': 109, 'num_layers': 3, 'dropout': 0.07257902095087465, 'lr': 0.0008528633859727372}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:28:01,920] Trial 39 finished with value: 0.4969650208950043 and parameters: {'hidden_size': 87, 'num_layers': 1, 'dropout': 0.3666830907848937, 'lr': 0.0006765170228720561}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:28:05,450] Trial 40 finished with value: 0.49792173504829407 and parameters: {'hidden_size': 228, 'num_layers': 1, 'dropout': 0.3676255682734518, 'lr': 0.0006848126550810074}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:28:08,885] Trial 41 finished with value: 0.49398085474967957 and parameters: {'hidden_size': 233, 'num_layers': 1, 'dropout': 0.37392266116072237, 'lr': 0.0006200217427812165}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:28:10,768] Trial 42 finished with value: 0.49587130546569824 and parameters: {'hidden_size': 91, 'num_layers': 1, 'dropout': 0.34635381787926095, 'lr': 0.0004734408969369719}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:28:12,600] Trial 43 finished with value: 0.48500409722328186 and parameters: {'hidden_size': 76, 'num_layers': 1, 'dropout': 0.3486776344035466, 'lr': 0.0004579836929483377}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:28:14,650] Trial 44 finished with value: 0.49164652824401855 and parameters: {'hidden_size': 97, 'num_layers': 1, 'dropout': 0.32982994960179524, 'lr': 0.00026161641604924936}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:28:16,553] Trial 45 finished with value: 0.4935147762298584 and parameters: {'hidden_size': 91, 'num_layers': 1, 'dropout': 0.43226998119255, 'lr': 0.00031376079268897767}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:28:19,793] Trial 46 finished with value: 0.49678048491477966 and parameters: {'hidden_size': 205, 'num_layers': 1, 'dropout': 0.3671921971357761, 'lr': 0.0007137093777806943}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:28:22,982] Trial 47 finished with value: 0.4916098117828369 and parameters: {'hidden_size': 206, 'num_layers': 1, 'dropout': 0.37300259234178745, 'lr': 0.000755317599632567}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:28:26,684] Trial 48 finished with value: 0.498553603887558 and parameters: {'hidden_size': 232, 'num_layers': 1, 'dropout': 0.31753414620068926, 'lr': 0.0006929087680506705}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:28:30,017] Trial 49 finished with value: 0.4959380626678467 and parameters: {'hidden_size': 223, 'num_layers': 1, 'dropout': 0.3218573013335709, 'lr': 0.0011256334656385145}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:28:33,546] Trial 50 finished with value: 0.4593544900417328 and parameters: {'hidden_size': 243, 'num_layers': 1, 'dropout': 0.22919165240100262, 'lr': 0.003628217926429619}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:28:37,921] Trial 51 finished with value: 0.49317407608032227 and parameters: {'hidden_size': 232, 'num_layers': 1, 'dropout': 0.39132124963501724, 'lr': 0.0006879599939906937}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:28:41,496] Trial 52 finished with value: 0.49181103706359863 and parameters: {'hidden_size': 217, 'num_layers': 1, 'dropout': 0.36317286978638097, 'lr': 0.0008866887899107652}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:28:44,568] Trial 53 finished with value: 0.4956238567829132 and parameters: {'hidden_size': 200, 'num_layers': 1, 'dropout': 0.4761498947325183, 'lr': 0.0005244877783285584}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:28:47,441] Trial 54 finished with value: 0.4858764111995697 and parameters: {'hidden_size': 187, 'num_layers': 1, 'dropout': 0.4060732269972896, 'lr': 0.0016317089524389777}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:28:51,025] Trial 55 finished with value: 0.4868687689304352 and parameters: {'hidden_size': 242, 'num_layers': 1, 'dropout': 0.2746377177646796, 'lr': 0.0008257149681317568}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:28:54,403] Trial 56 finished with value: 0.4903082847595215 and parameters: {'hidden_size': 225, 'num_layers': 1, 'dropout': 0.30946024668883165, 'lr': 0.00034895178270628695}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:28:57,685] Trial 57 finished with value: 0.49507376551628113 and parameters: {'hidden_size': 216, 'num_layers': 1, 'dropout': 0.42170592951162333, 'lr': 0.0006877655974815108}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:29:00,860] Trial 58 finished with value: 0.49423614144325256 and parameters: {'hidden_size': 206, 'num_layers': 1, 'dropout': 0.3845876412859983, 'lr': 0.0005257016274663919}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:29:03,797] Trial 59 finished with value: 0.48879775404930115 and parameters: {'hidden_size': 186, 'num_layers': 1, 'dropout': 0.3417450558820938, 'lr': 0.0011246513127073907}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:29:06,720] Trial 60 finished with value: 0.48457610607147217 and parameters: {'hidden_size': 177, 'num_layers': 1, 'dropout': 0.4413928747923439, 'lr': 0.000962766795571323}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:29:10,538] Trial 61 finished with value: 0.4889432191848755 and parameters: {'hidden_size': 226, 'num_layers': 1, 'dropout': 0.31490845583408306, 'lr': 0.0012119329813545757}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:29:14,094] Trial 62 finished with value: 0.49597403407096863 and parameters: {'hidden_size': 222, 'num_layers': 1, 'dropout': 0.3245290636330666, 'lr': 0.0006183172549405991}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:29:17,288] Trial 63 finished with value: 0.4943489134311676 and parameters: {'hidden_size': 212, 'num_layers': 1, 'dropout': 0.3578305123646047, 'lr': 0.0006155970077854036}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:29:20,747] Trial 64 finished with value: 0.4964289665222168 and parameters: {'hidden_size': 236, 'num_layers': 1, 'dropout': 0.25134694394322116, 'lr': 0.000767017264123754}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:29:24,296] Trial 65 finished with value: 0.4828014075756073 and parameters: {'hidden_size': 236, 'num_layers': 1, 'dropout': 0.15279431373665758, 'lr': 0.0014802615363911878}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:29:27,890] Trial 66 finished with value: 0.49674317240715027 and parameters: {'hidden_size': 249, 'num_layers': 1, 'dropout': 0.24198923616175866, 'lr': 0.0007765110769126202}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:29:31,560] Trial 67 finished with value: 0.4932761490345001 and parameters: {'hidden_size': 246, 'num_layers': 1, 'dropout': 0.2806903163815504, 'lr': 0.0009496738941794658}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:29:35,203] Trial 68 finished with value: 0.49799665808677673 and parameters: {'hidden_size': 247, 'num_layers': 1, 'dropout': 0.22501304475546224, 'lr': 0.0005310449377211683}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:29:38,286] Trial 69 finished with value: 0.4933883249759674 and parameters: {'hidden_size': 198, 'num_layers': 1, 'dropout': 0.410036240509484, 'lr': 0.0004644731392852436}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:30:01,170] Trial 70 finished with value: 0.48327282071113586 and parameters: {'hidden_size': 176, 'num_layers': 3, 'dropout': 0.3777559683389826, 'lr': 0.0005412736687868896}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:30:08,203] Trial 71 finished with value: 0.4959295690059662 and parameters: {'hidden_size': 248, 'num_layers': 1, 'dropout': 0.21479710248360892, 'lr': 0.0007240017489389976}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:30:17,216] Trial 72 finished with value: 0.4942304193973541 and parameters: {'hidden_size': 250, 'num_layers': 1, 'dropout': 0.25618349599401846, 'lr': 0.0008290574574113241}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:30:23,603] Trial 73 finished with value: 0.49468234181404114 and parameters: {'hidden_size': 256, 'num_layers': 1, 'dropout': 0.1917229296662658, 'lr': 0.0006036078988894652}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:30:26,748] Trial 74 finished with value: 0.4932279884815216 and parameters: {'hidden_size': 191, 'num_layers': 1, 'dropout': 0.24327888724093963, 'lr': 0.00036623964922498603}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:30:29,678] Trial 75 finished with value: 0.4912513196468353 and parameters: {'hidden_size': 158, 'num_layers': 1, 'dropout': 0.498490894721188, 'lr': 0.0009644285298309404}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:30:37,688] Trial 76 finished with value: 0.4924744665622711 and parameters: {'hidden_size': 231, 'num_layers': 2, 'dropout': 0.2259933384936775, 'lr': 0.0005034789004818902}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:30:45,034] Trial 77 finished with value: 0.4947487413883209 and parameters: {'hidden_size': 202, 'num_layers': 2, 'dropout': 0.270208364995042, 'lr': 0.00067788263376466}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:30:53,306] Trial 78 finished with value: 0.49281835556030273 and parameters: {'hidden_size': 240, 'num_layers': 2, 'dropout': 0.30613810433066124, 'lr': 0.00032771344300270373}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:30:56,166] Trial 79 finished with value: 0.49805840849876404 and parameters: {'hidden_size': 182, 'num_layers': 1, 'dropout': 0.20156784132032846, 'lr': 0.0004164782657532432}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:30:59,239] Trial 80 finished with value: 0.49809780716896057 and parameters: {'hidden_size': 166, 'num_layers': 1, 'dropout': 0.15454250007287418, 'lr': 0.0004204571232549689}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:31:01,957] Trial 81 finished with value: 0.4936811029911041 and parameters: {'hidden_size': 172, 'num_layers': 1, 'dropout': 0.160428798532548, 'lr': 0.0002729664491183675}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:31:04,681] Trial 82 finished with value: 0.4956792891025543 and parameters: {'hidden_size': 163, 'num_layers': 1, 'dropout': 0.1648953208543555, 'lr': 0.00042810405168041045}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:31:07,557] Trial 83 finished with value: 0.49481987953186035 and parameters: {'hidden_size': 183, 'num_layers': 1, 'dropout': 0.2058802323813242, 'lr': 0.00041105549705838335}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:31:10,761] Trial 84 finished with value: 0.49702945351600647 and parameters: {'hidden_size': 192, 'num_layers': 1, 'dropout': 0.13709342553613696, 'lr': 0.0005748446420306923}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:31:13,495] Trial 85 finished with value: 0.492742657661438 and parameters: {'hidden_size': 143, 'num_layers': 1, 'dropout': 0.14117033822321878, 'lr': 0.00024306943493854224}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:31:17,209] Trial 86 finished with value: 0.4949020445346832 and parameters: {'hidden_size': 191, 'num_layers': 1, 'dropout': 0.17660420499987134, 'lr': 0.0005654939711125475}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:31:23,319] Trial 87 finished with value: 0.4945593774318695 and parameters: {'hidden_size': 172, 'num_layers': 2, 'dropout': 0.10319964633718308, 'lr': 0.00029302753250976535}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:31:26,185] Trial 88 finished with value: 0.49577853083610535 and parameters: {'hidden_size': 156, 'num_layers': 1, 'dropout': 0.1369925593793909, 'lr': 0.0004873971316032913}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:31:28,930] Trial 89 finished with value: 0.49314817786216736 and parameters: {'hidden_size': 166, 'num_layers': 1, 'dropout': 0.19725623650242677, 'lr': 0.0003778094822018244}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:31:35,033] Trial 90 finished with value: 0.49134039878845215 and parameters: {'hidden_size': 181, 'num_layers': 2, 'dropout': 0.17782282660439377, 'lr': 0.00045501529362137436}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:31:38,017] Trial 91 finished with value: 0.4982788562774658 and parameters: {'hidden_size': 191, 'num_layers': 1, 'dropout': 0.3617302411854166, 'lr': 0.000637414079925347}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:31:39,805] Trial 92 finished with value: 0.49270501732826233 and parameters: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.39843635624606505, 'lr': 0.000665841514702692}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:31:42,708] Trial 93 finished with value: 0.498955100774765 and parameters: {'hidden_size': 174, 'num_layers': 1, 'dropout': 0.07542077992133694, 'lr': 0.0005404983842849473}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:31:45,757] Trial 94 finished with value: 0.49789977073669434 and parameters: {'hidden_size': 192, 'num_layers': 1, 'dropout': 0.04548562653181873, 'lr': 0.0005681108898654175}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:31:48,458] Trial 95 finished with value: 0.4946833550930023 and parameters: {'hidden_size': 161, 'num_layers': 1, 'dropout': 0.03781242953311523, 'lr': 0.0003292842498693223}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:31:51,477] Trial 96 finished with value: 0.48324671387672424 and parameters: {'hidden_size': 187, 'num_layers': 1, 'dropout': 0.05533866925020818, 'lr': 0.0001015994499970047}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:31:54,347] Trial 97 finished with value: 0.4913311004638672 and parameters: {'hidden_size': 174, 'num_layers': 1, 'dropout': 0.0141259661591914, 'lr': 0.00040934895106975455}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:31:57,306] Trial 98 finished with value: 0.49195197224617004 and parameters: {'hidden_size': 167, 'num_layers': 1, 'dropout': 0.09447338953407416, 'lr': 0.0005047518890308221}. Best is trial 28 with value: 0.4990440607070923.
# [I 2025-06-23 22:32:00,310] Trial 99 finished with value: 0.494301438331604 and parameters: {'hidden_size': 180, 'num_layers': 1, 'dropout': 0.039987600799112726, 'lr': 0.0008726817208931229}. Best is trial 28 with value: 0.4990440607070923.

# %%
best_params = study.best_trial.params
print(best_params)
# Out:
# {'hidden_size': 176, 'num_layers': 2, 'dropout': 0.33538865521448935, 'lr': 0.001118455827194482}

# %%
best_model = LSTM(
    input_size=30,
    hidden_size=best_params["hidden_size"],
    num_layers=best_params["num_layers"],
    dropout=best_params["dropout"] if best_params["num_layers"] > 1 else 0.0
)

optimizer = torch.optim.Adam(best_model.parameters(), lr=best_params["lr"])
loss_fn = nn.MSELoss()

for epoch in range(31):
    best_model.train()
    for xb, yb in train_loader:
        pred = best_model(xb)
        loss = loss_fn(pred, yb)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    if epoch % 5 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item():.4f}")
# Out:
# Epoch 0, Loss: 0.5620
# Epoch 5, Loss: 0.3845
# Epoch 10, Loss: 0.4680
# Epoch 15, Loss: 0.4007
# Epoch 20, Loss: 0.5174
# Epoch 25, Loss: 0.4665
# Epoch 30, Loss: 0.3513

# %%
best_model.eval()
preds, targets = [], []

with torch.no_grad():
    for xb, yb in val_loader:
        out = best_model(xb)
        preds.append(out.numpy())
        targets.append(yb.numpy())

preds = np.concatenate(preds, axis=0)
targets = np.concatenate(targets, axis=0)

preds_orig = y_scaler.inverse_transform(preds)
targets_orig = y_scaler.inverse_transform(targets)

# %%
print("R² Score:", r2_score(targets_orig, preds_orig))
print("MAE:", mean_absolute_error(targets_orig, preds_orig))
print("MSE:", mean_squared_error(targets_orig, preds_orig))
print("RMSE:", np.sqrt(mean_squared_error(targets_orig, preds_orig)))
# Out:
# R² Score: 0.45383429527282715
# MAE: 0.11962541937828064
# MSE: 0.03243095800280571
# RMSE: 0.18008597392025208

# %%
target_names = ['next_games_played_per', 'next_goals_per_game', 'next_assists_per_game']
for i, name in enumerate(target_names):
    print(f"{name}")
    print("R²:", r2_score(targets_orig[:, i], preds_orig[:, i]))
    print("MAE:", mean_absolute_error(targets_orig[:, i], preds_orig[:, i]))
    print("MSE:", mean_squared_error(targets_orig[:, i], preds_orig[:, i]))
    print("RMSE:", np.sqrt(mean_squared_error(targets_orig[:, i], preds_orig[:, i])))
# Out:
# next_games_played_per
# R²: 0.22282147407531738
# MAE: 0.20151984691619873
# MSE: 0.0726410523056984
# RMSE: 0.26952004063835105
# next_goals_per_game
# R²: 0.5612466335296631
# MAE: 0.063809335231781
# MSE: 0.008928364142775536
# RMSE: 0.09449002139260809
# next_assists_per_game
# R²: 0.5774340629577637
# MAE: 0.09354712069034576
# MSE: 0.015723474323749542
# RMSE: 0.1253932786226979

# %%
import joblib

# %%
torch.save(best_model.state_dict(), "../models/lstm_nhl_model.pt")
joblib.dump(X_scaler, "../models/X_scaler.pkl")
joblib.dump(y_scaler, "../models/y_scaler.pkl")
# Out:
# ['../models/y_scaler.pkl']
